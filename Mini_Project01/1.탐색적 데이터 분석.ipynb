# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계1 : 탐색적 데이터 분석

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **기본 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature와 중요하지 않은 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.

# %% [markdown]
# ### (2) 미션2
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project3/'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩
#     - pandas, numpy,matplotlib,seaborn, joblib 을 로딩하고
#     필요한 라이브러리를 로딩합니다.
#     <br>(분류 모델에서는 이번에 RandomForestClassifier를 씁니다. 더 많은 분류 모델을 써도 됩니다!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# * 제공 함수 생성
#     * 변수 중요도를 시각화할 수 있는 함수를 제공합니다.
#     * 입력 :
#         * importance : 트리모델의 변수 중요도(예: model.feature_importances_)
#         * names : 변수 이름 목록(예 : x_train.columns)
#         * result_only  : 변수 중요도 순으로 데이터프레임만 return할지, 그래프도 포함할지 결정. False이면 결과 데이터프레임 + 그래프
#         * topn : 중요도 상위 n개만 표시. all 이면 전체.
#     * 출력 :
#         * 중요도 그래프 : 중요도 내림차순으로 정렬
#         * 중요도 데이터프레임 : 중요도 내림차순으로 정렬

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %%
# 주어진 데이터 셋을 불러오세요.
data01_train = pd.read_csv(path + 'data01_train.csv')
data01_test = pd.read_csv(path + 'data01_test.csv')
features = pd.read_csv(path + 'features.csv')

# %%
#불필요한 칼럼을 삭제하세요.
data01_train = data01_train.drop('subject', axis=1)
data01_test = data01_test.drop('subject', axis=1)

# %% [markdown]
# ## 2.데이터 분석 : 기본정보 살펴보기

# %% [markdown]
# ### (1) 기본정보 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - 불러온 데이터의 형태, 기초통계량, 정보 등을 확인합니다.

# %%
# 전체 데이터의 행, 열 개수를 확인
print("data01_train :", data01_train.shape)
print("data01_test :", data01_test.shape)
print("features :", features.shape)
# Out:
# data01_train : (5881, 562)
# data01_test : (1471, 562)
# features : (561, 4)

# %%
# 전체 데이터의 상위 5개 행 확인
print(data01_train.head(5))
print(data01_test.head(5))
print(features.head(5))
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
# ...

# %%
# 전체 데이터의 수치형 변수 분포 확인
print(data01_train.describe())
print(data01_test.describe())
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# ...

# %%
#전체 데이터의 모든 변수 확인
print(list(data01_train.columns))
print(list(data01_test.columns))
print(list(features.columns))
# Out:
# ['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z', 'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z', 'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z', 'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z', 'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y', 'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y', 'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y', 'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1', 'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3', 'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1', 'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3', 'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1', 'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3', 'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y', 'tBodyAcc-correlation()-X,Z', 'tBodyAcc-correlation()-Y,Z', 'tGravityAcc-mean()-X', 'tGravityAcc-mean()-Y', 'tGravityAcc-mean()-Z', '
# ...

# %%
#(추가) 다양하게 기본 정보들을 확인하세요!
print(data01_train.isna().sum())
print(data01_test.isna().sum())
print(features.isna().sum())
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Activity                                0
# Length: 562, dtype: int64
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Activity                                0
# ...

# %% [markdown]
# ### (2) 목표 변수 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - target인 'Activity'에 대해 단변량 분석을 수행합니다.
#     - 범주의 종류, 범주별 빈도수 및 비율 등

# %%
# Activity 에 대해서 단변량 분석을 시행합니다. (범주별 빈도수, 종류, 비율, 시각화도 해보기!)

# %%
print(data01_train['Activity'].unique())
# Out:
# ['STANDING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS' 'WALKING_UPSTAIRS'
#  'SITTING']

# %%
print(data01_train['Activity'].value_counts())
# Out:
# Activity
# LAYING                1115
# STANDING              1087
# SITTING               1032
# WALKING                998
# WALKING_UPSTAIRS       858
# WALKING_DOWNSTAIRS     791
# Name: count, dtype: int64

# %%
# 범주별 비율
activity_ratio = data01_train['Activity'].value_counts(normalize=True) * 100
print(activity_ratio)
# Out:
# Activity
# LAYING                18.959361
# STANDING              18.483251
# SITTING               17.548036
# WALKING               16.969903
# WALKING_UPSTAIRS      14.589356
# WALKING_DOWNSTAIRS    13.450094
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='Activity', data=data01_train)
plt.title('Activity Distribution')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### (3) 센서 그룹 데이터: features

# %% [markdown]
# * **세부 요구사항**
#     - feature 이름에 대한 계층 구조별로 변수의 수를 카운트 해 봅시다.
#         - sensor 별 변수의 개수
#         - agg(regation) 별 변수의 개수
#         - axis 별 변수의 개수

# %%
#센서 그룹 데이터의 'sensor'변수의 값 확인
print(features['sensor'].value_counts())
# Out:
# sensor
# fBodyGyro               79
# fBodyAccJerk            79
# fBodyAcc                79
# tBodyAcc                40
# tGravityAcc             40
# tBodyAccJerk            40
# tBodyGyroJerk           40
# tBodyGyro               40
# tGravityAccMag          13
# tBodyAccMag             13
# tBodyGyroJerkMag        13
# tBodyGyroMag            13
# tBodyAccJerkMag         13
# fBodyAccMag             13
# fBodyBodyAccJerkMag     13
# fBodyBodyGyroMag        13
# fBodyBodyGyroJerkMag    13
# angle                    7
# Name: count, dtype: int64

# %%
#센서 그룹 데이터의 'agg'변수의 값 확인
print(features['agg'].value_counts())
# Out:
# agg
# bandsEnergy()        126
# arCoeff()             60
# std()                 33
# mad()                 33
# max()                 33
# energy()              33
# min()                 33
# entropy()             33
# iqr()                 33
# mean()                33
# sma()                 17
# correlation()         15
# kurtosis()            13
# meanFreq()            13
# skewness()            13
# maxInds               13
# arCoeff()4             5
# arCoeff()2             5
# arCoeff()3             5
# arCoeff()1             5
# tBodyAccMean           1
# tBodyAccJerkMean       1
# tBodyGyroMean          1
# tBodyGyroJerkMean      1
# X                      1
# Y                      1
# Z                      1
# Name: count, dtype: int64

# %%
#센서 그룹 데이터의 'axis'변수의 값 확인
print(features['axis'].value_counts())
# Out:
# axis
# X              76
# Y              76
# Z              76
# gravityMean     6
# X,2             5
#                ..
# 17,32.2         2
# 49,64.2         2
# 1,24.2          2
# 25,48.2         2
# gravity         1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ## 3.미션1 : 데이터 분석1

# %% [markdown]
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **트리 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.
# * 3) **각 feature 그룹별 중요도**도 파악해보며 EDA를 수행
#     * Feature 이름에는 계층구조를 담고 있습니다. 그렇다 보니 feature들을 적절하게 그룹으로 묶을 수 있습니다.
#     * 참고로, feature 그룹의 중요도는 개별 feature 중요도의 합으로 계산할 수 있습니다.

# %% [markdown]
# ### (1) 기본모델링 + 변수중요도 추출

# %% [markdown]
# * **세부 요구사항**
#     - 모델링을 위한 기본 전처리를 수행합니다.
#         - 주어진 데이터에서는 x, y로 나누고 train과 validation 분할 수행
#     - 트리기반 알고리즘을 이용하여 모델링을 합니다.
#         - 랜덤포레스트 권장 : 랜덤포레스트는 튜닝 없이 하이퍼파리미터의 기본값로도 적절한 성능의 모델을 생성할 수 있습니다.
#     - 변수 중요도 추출
#         - 사용자정의함수로 생성한 plot_feature_importance 을 이용
#         - 변수중요도 파악및 결과 저장

# %% [markdown]
# #### 1) 데이터 전처리

# %%
# 데이터 분할을 위한 전처리
from sklearn.model_selection import train_test_split

# x, y 데이터 설정
target = 'Activity'
x = data01_train.drop(target, axis=1)
y = data01_train[target]

x_train, x_val, y_train, y_val = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# #### 2) 모델링

# %%
# 모델 생성 및 학습
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# 평가
from sklearn.metrics import classification_report

y_pred = model.predict(x_val)
print(classification_report(y_val, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       223
#            SITTING       0.96      0.96      0.96       206
#           STANDING       0.97      0.96      0.96       218
#            WALKING       1.00      0.98      0.99       200
# WALKING_DOWNSTAIRS       0.98      0.98      0.98       158
#   WALKING_UPSTAIRS       0.97      1.00      0.99       172
#
#           accuracy                           0.98      1177
#          macro avg       0.98      0.98      0.98      1177
#       weighted avg       0.98      0.98      0.98      1177

# %% [markdown]
# #### 3) 변수 중요도 추출

# %%
# 변수 중요도 추출(시각화로 나타내기)
fi_df = plot_feature_importance(model.feature_importances_, x_train.columns)
plt.show()

# %% [markdown]
# ### (2) 중요도 기반 feature 분석

# %% [markdown]
# * **세부 요구사항**
#     - 상위 n, 하위 m 개의 변수를 선정
#     - 선정된 변수(feature)와 target 간의 관계를 kdeplot으로 그리기

# %% [markdown]
# #### 1) 상위 5, 하위 5개 변수 선정

# %%
# 중요도 상위 top 5
top5_features = fi_df['feature_name'].head(5).tolist()
print(top5_features)
# Out:
# ['tGravityAcc-mean()-X', 'angle(X,gravityMean)', 'tGravityAcc-max()-X', 'tGravityAcc-energy()-X', 'tGravityAcc-mean()-Y']

# %%
# 중요도 하위 top 5
bottom5_features = fi_df['feature_name'].tail(5).tolist()
print(bottom5_features)
# Out:
# ['fBodyBodyGyroMag-iqr()', 'fBodyAccJerk-bandsEnergy()-49,56.1', 'fBodyBodyAccJerkMag-min()', 'fBodyBodyGyroJerkMag-entropy()', 'fBodyAcc-bandsEnergy()-49,64']

# %% [markdown]
# #### 2) 상위 5개 변수에 대한 분석
#         - 위에서 나온 상위 5개의 변수를 선정해서 target과의 관계를 kdeplot으로 그려보세요!

# %%
#1위 :
fi_df.iloc[0]['feature_name']
# Out:
# 'tGravityAcc-mean()-X'

# %%
#2위: vvvvv
fi_df.iloc[1]['feature_name']
# Out:
# 'angle(X,gravityMean)'

# %%
for feature in top5_features:
    plt.figure(figsize=(4, 3))
    sns.kdeplot(data=data01_train, x=feature, hue=target, common_norm=False)
    plt.title(feature)
    plt.show()

# %% [markdown]
# #### 3) 하위 5개 변수에 대한 분석
#         - 위에서 하위 5개의 변수를 선정해서 target과의 관계를 kdeplot으로 그려보세요!

# %%
#1위 :
fi_df.iloc[-1]['feature_name']
# Out:
# 'fBodyAcc-bandsEnergy()-49,64'

# %%
#2위:
fi_df.iloc[-2]['feature_name']
# Out:
# 'fBodyBodyGyroJerkMag-entropy()'

# %%
for feature in bottom5_features:
    plt.figure(figsize=(4, 3))
    sns.kdeplot(data=data01_train, x=feature, hue=target, common_norm=False)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## 4.미션2 : 데이터 분석2

# %% [markdown]
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ### (1) 정적/동적 행동으로 구분하여 분석하기

# %% [markdown]
# * **세부 요구사항**
#     - Target인 Activity를 is_dynamic 변수로 변경하시오.
#         * 값 0 : STANDING, SITTING, LAYING
#         * 값 1 : WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS
#     - is_dynamic을 예측하기 위한 기본 모델을 생성하시오.
#         * x, is_dynamic을 이용하여 train과 validation으로 데이터 분할
#         * 기본 모델링
#     - is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석하시오.

# %% [markdown]
# #### 1) is_dynamic 추가

# %%
#is dynamic 변수를 추가하세요(값 0, 값 1 확인해서!)
data01_train['is_dynamic'] = data01_train['Activity'].apply(lambda x: 0 if x in ['STANDING', 'SITTING', 'LAYING'] else 1)

# %% [markdown]
# #### 2) 기본모델 생성

# %%
#데이터 분할 진행(train:val = 8:2 혹은 7:3 권장)
x = data01_train.drop(['Activity', 'is_dynamic'], axis=1)
y = data01_train['is_dynamic']

x_train, x_val, y_train, y_val = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %%
#RandomForestClassifier로 모델링 진행
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### 3) 변수중요도 상위 5개 분석

# %%
# is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석!

# %% [markdown]
# * 미션1에서 했던 것 처럼 상위 5개의 변수 데이터를 탐색해보기!

# %%
# 변수 중요도 추출
fi_df_dynamic = plot_feature_importance(model.feature_importances_, x_train.columns, result_only=True)

# %%
#1위:
fi_df_dynamic.iloc[0]['feature_name']
# Out:
# 'fBodyAccJerk-max()-X'

# %%
#2위:
fi_df_dynamic.iloc[1]['feature_name']
# Out:
# 'fBodyAccJerk-bandsEnergy()-1,16'

# %%
# 상위 5개 변수 출력
top5_features_dynamic = fi_df_dynamic['feature_name'].head(5).tolist()
print(top5_features_dynamic)
# Out:
# ['fBodyAccJerk-max()-X', 'fBodyAccJerk-bandsEnergy()-1,16', 'tBodyAccJerk-std()-X', 'tBodyGyroJerk-iqr()-Z', 'fBodyAccJerk-std()-X']

# %%
# 상위 5개 변수에 대한 kdeplot
for feature in top5_features_dynamic:
    plt.figure(figsize=(4, 3))
    sns.kdeplot(data=data01_train, x=feature, hue='is_dynamic', common_norm=False)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## 5.특성 중요도 저장하기

# %% [markdown]
# * **세부 요구사항**
#     - 지금까지 변수 중요도를 다양한 관점에서 뽑고 분석을 해 보았습니다.
#         - 관점1 : 6개 행동 구분
#         - 관점2 : 동적, 정적 행동 구분
#     - 모든 관점의 변수 중요도를 하나로 합친 후 저장
#         - merge를 이용하여 features와 합칩니다.
#         - joblib 패키지의 dump를 이용하여 결과를 저장합니다.

# %% [markdown]
# ### (1) 하나로 합치기
# * 합치기 위해서는 중요도 결과에서 feature_importance 칼럼 이름을 수정해야 합니다.
# * pd.merge를 이용해서 하나씩 합치는 작업을 반복 합니다.

# %% [markdown]
# #### 1) 이름변경

# %%
# tip : rename을 써서 칼럼 이름 수정을 해야합니다!
fi_df.rename(columns={'feature_importance': 'importance_activity'}, inplace=True)
fi_df_dynamic.rename(columns={'feature_importance': 'importance_is_dynamic'}, inplace=True)

# %% [markdown]
# #### 2) 합치기

# %%
# merge 해서 2개를 합치는 작업하기
feature_importance = pd.merge(features, fi_df[['feature_name', 'importance_activity']], on='feature_name', how='left')
feature_importance = pd.merge(feature_importance, fi_df_dynamic[['feature_name', 'importance_is_dynamic']], on='feature_name', how='left')

# %%
feature_importance
# Out:
#        sensor                agg         axis  \
# 0    tBodyAcc             mean()            X
# 1    tBodyAcc             mean()            Y
# 2    tBodyAcc             mean()            Z
# 3    tBodyAcc              std()            X
# 4    tBodyAcc              std()            Y
# ..        ...                ...          ...
# 556     angle      tBodyGyroMean  gravityMean
# 557     angle  tBodyGyroJerkMean  gravityMean
# 558     angle                  X  gravityMean
# 559     angle                  Y  gravityMean
# 560     angle                  Z  gravityMean
#
#                              feature_name  importance_activity  \
# 0                       tBodyAcc-mean()-X             0.000241
# 1                       tBodyAcc-mean()-Y             0.000279
# 2                       tBodyAcc-mean()-Z             0.000132
# 3                        tBodyAcc-std()-X             0.004506
# 4                        tBodyAcc-std()-Y             0.000206
# ...

# %% [markdown]
# ### (2) 저장하기
# * joblib.dump를 이용하시오.
# * 저장할 파일의 확장자는 보통 .pkl 입니다.

# %%
# joblib.dump 이용해서 colab에 .pkl 파일에 저장하기(tip: path + '파일 이름.pkl')
import joblib

joblib.dump(feature_importance, path + 'feature_importance.pkl')
# Out:
# ['/content/drive/MyDrive/project3/feature_importance.pkl']

# %% [markdown]
# #### 고생하셨습니다! 이제 기본 모델링을 해봅시다.
